# %% [markdown]
# ## Merging all files in one Location

# %%
import os
import shutil

# Set the path to the main folder that contains all subfolders
source_root = 'C:/Users/Admin/Downloads/Audio_Speech_Actors_01-24'  # Change this
destination_folder = 'C:/Users/Admin/OneDrive/Desktop/AudioFiles'  # Change this

# Create destination folder if it doesn't exist
os.makedirs(destination_folder, exist_ok=True)

# Loop through all subfolders and their files
for root, dirs, files in os.walk(source_root):
    for file in files:
        if file.lower().endswith(('.mp3', '.wav', '.aac', '.flac', '.ogg')):  # Add more formats if needed
            source_path = os.path.join(root, file)
            dest_path = os.path.join(destination_folder, file)

            # If file with same name exists, rename to avoid overwrite
            base, ext = os.path.splitext(file)
            counter = 1
            while os.path.exists(dest_path):
                dest_path = os.path.join(destination_folder, f"{base}_{counter}{ext}")
                counter += 1

            shutil.copy2(source_path, dest_path)
            print(f"Copied: {source_path} -> {dest_path}")
# Out:
# Copied: C:/Users/Admin/Downloads/Audio_Speech_Actors_01-24\Actor_01\03-01-01-01-01-01-01.wav -> Audio_Files\03-01-01-01-01-01-01.wav
# Copied: C:/Users/Admin/Downloads/Audio_Speech_Actors_01-24\Actor_01\03-01-01-01-01-02-01.wav -> Audio_Files\03-01-01-01-01-02-01.wav
# Copied: C:/Users/Admin/Downloads/Audio_Speech_Actors_01-24\Actor_01\03-01-01-01-02-01-01.wav -> Audio_Files\03-01-01-01-02-01-01.wav
# Copied: C:/Users/Admin/Downloads/Audio_Speech_Actors_01-24\Actor_01\03-01-01-01-02-02-01.wav -> Audio_Files\03-01-01-01-02-02-01.wav
# Copied: C:/Users/Admin/Downloads/Audio_Speech_Actors_01-24\Actor_01\03-01-02-01-01-01-01.wav -> Audio_Files\03-01-02-01-01-01-01.wav
# Copied: C:/Users/Admin/Downloads/Audio_Speech_Actors_01-24\Actor_01\03-01-02-01-01-02-01.wav -> Audio_Files\03-01-02-01-01-02-01.wav
# Copied: C:/Users/Admin/Downloads/Audio_Speech_Actors_01-24\Actor_01\03-01-02-01-02-01-01.wav -> Audio_Files\03-01-02-01-02-01-01.wav
# ...

# %%
import os
import shutil

# Set the path to the main folder that contains all subfolders
source_root = 'C:/Users/Admin/Downloads/Audio_Song_Actors_01-24'  # Change this
destination_folder = 'Audio_Files'  # Change this

# Create destination folder if it doesn't exist
os.makedirs(destination_folder, exist_ok=True)

# Loop through all subfolders and their files
for root, dirs, files in os.walk(source_root):
    for file in files:
        if file.lower().endswith(('.mp3', '.wav', '.aac', '.flac', '.ogg')):  # Add more formats if needed
            source_path = os.path.join(root, file)
            dest_path = os.path.join(destination_folder, file)

            # If file with same name exists, rename to avoid overwrite
            base, ext = os.path.splitext(file)
            counter = 1
            while os.path.exists(dest_path):
                dest_path = os.path.join(destination_folder, f"{base}_{counter}{ext}")
                counter += 1

            shutil.copy2(source_path, dest_path)
            print(f"Copied: {source_path} -> {dest_path}")
# Out:
# Copied: C:/Users/Admin/Downloads/Audio_Song_Actors_01-24\Actor_01\03-02-01-01-01-01-01.wav -> Audio_Files\03-02-01-01-01-01-01.wav
# Copied: C:/Users/Admin/Downloads/Audio_Song_Actors_01-24\Actor_01\03-02-01-01-01-02-01.wav -> Audio_Files\03-02-01-01-01-02-01.wav
# Copied: C:/Users/Admin/Downloads/Audio_Song_Actors_01-24\Actor_01\03-02-01-01-02-01-01.wav -> Audio_Files\03-02-01-01-02-01-01.wav
# Copied: C:/Users/Admin/Downloads/Audio_Song_Actors_01-24\Actor_01\03-02-01-01-02-02-01.wav -> Audio_Files\03-02-01-01-02-02-01.wav
# Copied: C:/Users/Admin/Downloads/Audio_Song_Actors_01-24\Actor_01\03-02-02-01-01-01-01.wav -> Audio_Files\03-02-02-01-01-01-01.wav
# Copied: C:/Users/Admin/Downloads/Audio_Song_Actors_01-24\Actor_01\03-02-02-01-01-02-01.wav -> Audio_Files\03-02-02-01-01-02-01.wav
# Copied: C:/Users/Admin/Downloads/Audio_Song_Actors_01-24\Actor_01\03-02-02-01-02-01-01.wav -> Audio_Files\03-02-02-01-02-01-01.wav
# ...
